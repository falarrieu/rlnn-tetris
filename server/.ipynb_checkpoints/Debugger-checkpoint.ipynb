# %%
import numpy as np
import matplotlib.pyplot as plt
from MovementNN import MovementNN
from NNTrainer import NNTrainer

trainer = NNTrainer()
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <module>
#       4 from NNTrainer import NNTrainer
#       6 trainer = NNTrainer()
# ----> 7 trainer.train()
#
# File ~/school/rlnn-tetris/server/NNTrainer.py:233, in NNTrainer.train(self)
#     231         if done:
#     232             self.episode_durations.append(t + 1)
# --> 233             self.plot_all()
#     234             break
#     236 print('Complete')
#
# File ~/school/rlnn-tetris/server/NNTrainer.py:131, in NNTrainer.plot_all(self, show_result)
#     128         board[currentPoints[i].y, currentPoints[i].x] = 2
#     129     board_ax.imshow(board, cmap=gray_map.reversed(), vmin=0, vmax=3)
# --> 131 plt.pause(0.001)  # pause a bit so that plots are updated
#     132 if is_ipython:
#     133     if not show_result:
#
# ...
