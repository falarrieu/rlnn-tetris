# %%
import numpy as np
import matplotlib.pyplot as plt
from MovementNN import MovementNN
from NNTrainer import NNTrainer

trainer = NNTrainer()
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <module>
#       4 from NNTrainer import NNTrainer
#       6 trainer = NNTrainer()
# ----> 7 trainer.train()
#
# File ~/school/rlnn-tetris/server/NNTrainer.py:171, in NNTrainer.train(self)
#     169 state = torch.tensor(state, dtype=torch.float32, device=self.device).unsqueeze(0)
#     170 for t in count():
# --> 171     self.game.board.showBoard(self.game.currentPiece)
#     172     action = self.select_action(state)
#     173     # print(action)
#     174     # observation, reward, terminated, truncated, _ = env.step(action.item())
#
# File ~/school/rlnn-tetris/server/Board.py:42, in Board.showBoard(self, piece)
#      40     board[point.y, point.x] = 1
#      41 plt.imshow(board, cmap=gray_map.reversed(), vmin=0, vmax=2)
# ---> 42 display.display(plt.gcf())
#
# ...
